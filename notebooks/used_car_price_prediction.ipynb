# %% [markdown]
# **Authorship:** *Héctor Ayuso Martín*
#
# **Linkedin:** *https://www.linkedin.com/in/hector-ayuso-martin/*

# %% [markdown]
# # Initial EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# %%
sns.set_style("whitegrid")
pd.set_option("display.max_columns",None)

# %%
BASE_DIR = Path().resolve().parent
DATA_PATH = BASE_DIR / "data" / "raw" / "cars.csv"

# %%
df = pd.read_csv(DATA_PATH)

# %%
#General information

print(f'Dataset shape: \n{df.shape}')
print("\n----------------------------")
print(f'\nData types:\n {df.dtypes}')
print("\n----------------------------")
print(f'\nNull rows: \n{df.isnull().sum()}')
# Out:
# Dataset shape:
# (4340, 8)
#
# ----------------------------
#
# Data types:
#  name             object
# year              int64
# selling_price     int64
# km_driven         int64
# fuel             object
# seller_type      object
# transmission     object
# owner            object
# dtype: object
#
# ----------------------------
#
# Null rows:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
#Descriptive statistics
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %% [markdown]
# ### Selling_price distribution

# %%
fig, ax = plt.subplots(figsize=(10,5))

sns.histplot(df["selling_price"], bins=50, kde=True, ax=ax)

ax.set_title("Selling Price Distribution", fontsize=14, fontweight="bold")
ax.set_xlabel("Selling Price")
ax.set_ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# *The variable ``selling_price`` is strongly right-skewed.
# Most vehicles have low to medium prices, while only a few have extremely high values.
# It will be advisable to test a logarithmic transformation of the target.*

# %% [markdown]
# ### BOXPLOT precio (Outliers)

# %%
fig, ax = plt.subplots(figsize=(10,4))

sns.boxplot(x=df["selling_price"], ax=ax)

ax.set_title("Outliers in Selling Price", fontsize=14, fontweight="bold")
ax.set_xlabel("Selling Price")

plt.tight_layout()
plt.show()

# %% [markdown]
# *``selling_price`` contains a large number of extreme high values.
# The variable is highly skewed, and it will be advisable to evaluate a logarithmic transformation or a robust outlier treatment.*

# %% [markdown]
# ### Price VS Kilometers

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(
    data = df,
    x="km_driven",
    y="selling_price",
    alpha=0.4
    )
plt.title=("km vs price"),
plt.show()

# %% [markdown]
# *There is an inverse relationship between mileage and price, although with high dispersion.
# ``km_driven`` will be a relevant predictive variable, but it needs to be combined with other variables to capture the real value of the vehicle.*

# %% [markdown]
# ### Year VS Price

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(
    data=df,
    x="year",
    y="selling_price",
    alpha=0.6
)
plt.title=("Year Vs Price")
plt.show()

# %% [markdown]
# *There is a clear positive relationship between ``year`` and ``price``.
# More recent vehicles tend to have higher prices.
# The variable ``year`` (or a transformation such as ``car_age``) will be a key predictor.*

# %% [markdown]
# ### Fuel Counts

# %%
df["fuel"].value_counts()
# Out:
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64

# %% [markdown]
# *`fuel` is a relevant categorical variable.
# Diesel and Petrol dominate the dataset.
# Minor categories should be grouped to avoid sparsity and noise.*

# %% [markdown]
# ### Most common brands

# %%
df["brand"] = df["name"].str.strip().str.split().str[0]
df["brand"].value_counts().head(15)
# Out:
# brand
# Maruti        1280
# Hyundai        821
# Mahindra       365
# Tata           361
# Honda          252
# Ford           238
# Toyota         206
# Chevrolet      188
# Renault        146
# Volkswagen     107
# Skoda           68
# Nissan          64
# Audi            60
# BMW             39
# Fiat            37
# Name: count, dtype: int64

# %% [markdown]
# *``brand`` will be one of the most relevant categorical variables in the project.
# It captures market positioning, perceived value, and the vehicle segment.*

# %% [markdown]
# ### Average price per brand

# %%
df.groupby("brand")["selling_price"].mean().sort_values(ascending=False).head(15)
# Out:
# brand
# Land             3.609800e+06
# BMW              2.945385e+06
# Mercedes-Benz    2.776657e+06
# Volvo            2.556250e+06
# Jaguar           2.069166e+06
# Audi             1.931633e+06
# MG               1.842500e+06
# Jeep             1.530000e+06
# Isuzu            1.500000e+06
# Kia              1.300000e+06
# Toyota           9.243592e+05
# Mitsubishi       8.400000e+05
# Mahindra         5.877095e+05
# Ford             5.712731e+05
# Honda            5.381468e+05
# Name: selling_price, dtype: float64

# %% [markdown]
# *``brand`` shows clear structural differences in average price.
# It will be one of the most influential categorical variables in the model.*

# %%
df["transmission"].value_counts()
# Out:
# transmission
# Manual       3892
# Automatic     448
# Name: count, dtype: int64

# %% [markdown]
# *``transmission`` is a useful and likely predictive binary categorical variable.
# Although it is imbalanced, it has enough examples to provide value to the model.*

# %%
df["owner"].value_counts()
# Out:
# owner
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: count, dtype: int64

# %% [markdown]
# *``owner`` is an ordinal variable with strong business meaning.
# It should be transformed while preserving its natural order, since more previous owners are usually associated with lower vehicle value.*

# %%
df["seller_type"].value_counts()
# Out:
# seller_type
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: count, dtype: int64

# %% [markdown]
# *``seller_type`` is a relevant categorical variable that captures commercial context and trust in the sales channel.*

# %% [markdown]
# # Feature Engineering & Data Preprocessing

# %%
#inital data security process
df_model = df.copy()
df_model.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner    brand
# 0  Individual       Manual   First Owner   Maruti
# 1  Individual       Manual   First Owner   Maruti
# 2  Individual       Manual   First Owner  Hyundai
# 3  Individual       Manual   First Owner   Datsun
# 4  Individual       Manual  Second Owner    Honda

# %% [markdown]
# ---

# %% [markdown]
# ### Numerical variables

# %%
#We converted the variable 'year' into an integer called 'car_age', a variable much easier for the system to understand.
current_year = df_model["year"].max()
df_model['car_age'] = current_year - df_model['year']
df_model.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner    brand  car_age
# 0  Individual       Manual   First Owner   Maruti       13
# 1  Individual       Manual   First Owner   Maruti       13
# 2  Individual       Manual   First Owner  Hyundai        8
# 3  Individual       Manual   First Owner   Datsun        3
# 4  Individual       Manual  Second Owner    Honda        6

# %% [markdown]
# ---

# %%
#We created the "km_per_year" column. This is far superior to only looking at total kilometers, since a car with 120.000 km over 12 years is very different from one that reaches 120.000 km in just 2 years.
#The latter strongly suggest intensive use, so the model can take adventage of this new information.

df_model["km_per_year"] = (df_model["km_driven"] / (df_model["car_age"] + 1)).astype(int)
df_model.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner    brand  car_age  km_per_year
# 0  Individual       Manual   First Owner   Maruti       13         5000
# 1  Individual       Manual   First Owner   Maruti       13         3571
# 2  Individual       Manual   First Owner  Hyundai        8        11111
# 3  Individual       Manual   First Owner   Datsun        3        11500
# 4  Individual       Manual  Second Owner    Honda        6        20142

# %% [markdown]
# ---

# %% [markdown]
# ### Categorical Variables

# %%
#Gouping fuel types
df_model["fuel"].value_counts()
# Out:
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64

# %%
df_model["fuel"] = df_model["fuel"].replace({
    "CNG":"Other",
    "LPG":"Other",
    "Electric":"Other"
})

# %%
df_model["fuel"].value_counts()
# Out:
# fuel
# Diesel    2153
# Petrol    2123
# Other       64
# Name: count, dtype: int64

# %% [markdown]
# ---

# %%
# # The variable "owner" has high value, since it has a natural order. The more previous owners a vehicle had, the lower its value. Therefore, we will use Ordinal Econding.
# df_model["owner"].value_counts()

# %%
owner_mapping = {

    "Test Drive Car" : 0,
    "First Owner" : 1,
    "Second Owner" : 2,
    "Third Owner" : 3,
    "Fourth & Above Owner" : 4
}

# %%
df_model["owner"] = df_model["owner"].map(owner_mapping).astype("Int64")

# %%
df_model["owner"].value_counts().sort_index()
# Out:
# owner
# 0      17
# 1    2832
# 2    1106
# 3     304
# 4      81
# Name: count, dtype: Int64

# %% [markdown]
# ---

# %%
#We can observe a problem. To resolve it, we change "Land" to "Land Rover"
df_model["brand"].value_counts().head(20)
# Out:
# brand
# Maruti           1280
# Hyundai           821
# Mahindra          365
# Tata              361
# Honda             252
# Ford              238
# Toyota            206
# Chevrolet         188
# Renault           146
# Volkswagen        107
# Skoda              68
# Nissan             64
# Audi               60
# BMW                39
# Fiat               37
# Datsun             37
# Mercedes-Benz      35
# Jaguar              6
# Mitsubishi          6
# Land                5
# Name: count, dtype: int64

# %%
df_model["brand"] = df_model["brand"].replace({
    "Land":"Land Rover"
})

# %%
#We are going to grout the brands with few examples into "Other". This action improves the quality of our data.
#Variables with very few examples do not provide much Learning value for the model and may introduce noise.

brand_counts = df_model["brand"].value_counts()
rare_brands = brand_counts[brand_counts < 10].index
df_model["brand"] = df_model["brand"].replace(rare_brands,"Other")

# %%
df_model["brand"].value_counts().head(20)
# Out:
# brand
# Maruti           1280
# Hyundai           821
# Mahindra          365
# Tata              361
# Honda             252
# Ford              238
# Toyota            206
# Chevrolet         188
# Renault           146
# Volkswagen        107
# Skoda              68
# Nissan             64
# Audi               60
# BMW                39
# Datsun             37
# Fiat               37
# Other              36
# Mercedes-Benz      35
# Name: count, dtype: int64

# %% [markdown]
# # Modeling Phase

# %% [markdown]
# The correct order in modeling phase is:
#
# - Define X and y
# - Detect numerical/categorical columns
# - Split into train/test
# - Build the pipeline with those lists
# - Fit on the training set
# - Evaluate on the test set

# %%
df_model.columns
df_model.to_csv("../data/processed/cars_processed.csv", index=False)

# %%
#We keep the columns that we want as features, as well as the target 'y'. We remove everything that is not worth keeping, such as the full name column or the year column
X = df_model.drop(columns=[
    "selling_price",
    "name",
    "year"
    ])

y = df_model["selling_price"]

# %%
X.head(2)
# Out:
#    km_driven    fuel seller_type transmission  owner   brand  car_age  \
# 0      70000  Petrol  Individual       Manual      1  Maruti       13
# 1      50000  Petrol  Individual       Manual      1  Maruti       13
#
#    km_per_year
# 0         5000
# 1         3571

# %% [markdown]
# ---

# %%
#We are going to separate the features into two different classes: Numerical and Categorical.

numerical_features = X.select_dtypes(include=["Int64","int64","float64"]).columns.tolist()

categorical_features = X.select_dtypes(include=["object"]).columns.tolist()

# %% [markdown]
# ---

# %%
#Making the data split.
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=7
)

# %%
#We are going to verify the data split.
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3472, 8), (868, 8), (3472,), (868,))

# %%
#I'm going to build the baseline model: Linear Regression.

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num","passthrough", numerical_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"),categorical_features)
    ]
)

# %%
model = Pipeline(steps=[
    ("preprocessor",preprocessor),
    ("regressor",LinearRegression())
])

# %%
model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', 'passthrough',
#                                                   ['km_driven', 'owner',
#                                                    'car_age', 'km_per_year']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['fuel', 'seller_type',
#                                                    'transmission',
#                                                    'brand'])])),
#                 ('regressor', LinearRegression())])

# %%
preds = model.predict(X_test)

# %%
#Observing how well it has performed

from sklearn.metrics import mean_absolute_error, mean_squared_error ,r2_score
import numpy as np

mae = mean_absolute_error(y_test,preds)
rmse = np.sqrt(mean_squared_error(y_test,preds))
r2 = r2_score(y_test,preds)

print("MAE:", round(mae,2))
print("RMSE:",round(rmse,2))
print("R^2:",round(r2,2))
# Out:
# MAE: 209395.38
# RMSE: 371532.5
# R^2: 0.51

# %% [markdown]
# ---

# %% [markdown]
# ### Baseline Metrics:
#
# - MAE: 209395.4
# - RMSE: 371532.5
# - R^2: 0.51
#
#
# *The model makes an average error of 209,395.38 monetary units (MAE). When the model makes large mistakes, those errors weigh more heavily, like 371,531.50 (RMSE). It xplains approximately 51% of the price behavior(R^2)*

# %%
#Second model: Random Forest Regressor. I'm going to use the same preprocesor in the new pipeline.

from sklearn.ensemble import RandomForestRegressor

rf_model = Pipeline(steps=[
    ("preprocessor",preprocessor),
    ("regressor", RandomForestRegressor(
        n_estimators=100,
        random_state=7,
        n_jobs=-1
    ))
])

# %%
rf_model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', 'passthrough',
#                                                   ['km_driven', 'owner',
#                                                    'car_age', 'km_per_year']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['fuel', 'seller_type',
#                                                    'transmission',
#                                                    'brand'])])),
#                 ('regressor',
#                  RandomForestRegressor(n_jobs=-1, random_state=7))])

# %%
rf_model_preds = rf_model.predict(X_test)

# %%
#Metrics:

rf_mae = mean_absolute_error(y_test,rf_model_preds)
rf_rmse = np.sqrt(mean_squared_error(y_test,rf_model_preds))
rf_r2 = r2_score(y_test,rf_model_preds)

print("RF MAE:" , round(rf_mae,2))
print("RF RMSE:" , round(rf_rmse,2))
print("RF R2:", round(rf_r2, 2))
# Out:
# RF MAE: 113032.43
# RF RMSE: 201630.34
# RF R2: 0.86

# %%
#Strong improvement. Comparative graphs.
fig, ax = plt.subplots(figsize=(8, 6))

ax.scatter(y_test, rf_model_preds, alpha=0.6)

ax.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    color="red",
    linestyle="--"
)

ax.set_xlabel("Actual Price")
ax.set_ylabel("Predicted Price")
ax.set_title("Random Forest: Actual vs Predicted")

plt.show()

# %% [markdown]
# *The scatter plot shows a strong positive relationship between actual and predicted prices, indicating that the Random Forest model performs well overall. Most points are concentrated close to the diagonal reference line, which represents perfect predictions. This suggests that the model captures price patterns accurately.*

# %% [markdown]
# ---

# %%
 #Testing XGBoost. Data preparation for early stopping. Until now, the X_train and X_test split was valid. For early stopping, a subdivision into 3 sets is necessary.

from xgboost import XGBRegressor

X_train_main, X_valid, y_train_main, y_valid = train_test_split(
    X_train,
    y_train,
    test_size=0.2,
    random_state=7
)

# %%
#Adjustments to the preprocessor to include the validation set
preprocessor.fit(X_train_main)

X_train_main_processed = preprocessor.transform(X_train_main)
X_valid_processed = preprocessor.transform(X_valid)
X_test_processed = preprocessor.transform(X_test)

# %%
xgb_model = XGBRegressor(
    n_estimators=1000,#ajá!;)
    learning_rate=0.05,
    max_depth=6,
    random_state=7,
    n_jobs=-1,
    early_stopping_rounds=50#yeah!
)

# %%
xgb_model.fit(
    X_train_main_processed,
    y_train_main,
    eval_set=[(X_valid_processed,y_valid)],
    verbose=False
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#              n_jobs=-1, num_parallel_tree=None, ...)

# %%
xgb_preds = xgb_model.predict(X_test_processed)

xgb_mae = mean_absolute_error(y_test, xgb_preds)
xgb_rmse = np.sqrt(mean_squared_error(y_test, xgb_preds))
xgb_r2 = r2_score(y_test, xgb_preds)

print(f"XGB MAE: {xgb_mae:.2f}")
print(f"XGB RMSE: {xgb_rmse:.2f}")
print(f"XGB R2: {xgb_r2:.2f}")
print(f"Best iteration: {xgb_model.best_iteration}")
# Out:
# XGB MAE: 108133.11
# XGB RMSE: 178180.01
# XGB R2: 0.89
# Best iteration: 365

# %% [markdown]
# ---

# %%
#Testing CatBoost

from catboost import CatBoostRegressor

# %%
cat_model = CatBoostRegressor(
    iterations=2000,
    learning_rate=0.05,
    depth=6,
    loss_function="RMSE",
    eval_metric="RMSE",
    random_seed=7,
    verbose=False
)

# %%
#Train with early-stopping. Using data without One-Hot encode. (x_train_main,x_valid,x_test)
cat_model.fit(
    X_train_main,
    y_train_main,
    cat_features=categorical_features,
    eval_set=(X_valid, y_valid),
    use_best_model=True,
    early_stopping_rounds=50
)
# Out:
# CatBoostRegressor(depth=6, eval_metric='RMSE', iterations=2000, learning_rate=0.05, loss_function='RMSE', random_seed=7, verbose=False)

# %%
cat_preds = cat_model.predict(X_test)

# %%
cat_mae = mean_absolute_error(y_test, cat_preds)
cat_rmse = np.sqrt(mean_squared_error(y_test, cat_preds))
cat_r2 = r2_score(y_test, cat_preds)

print(f"CatBoost MAE: {cat_mae:.2f}")
print(f"CatBoost RMSE: {cat_rmse:.2f}")
print(f"CatBoost R2: {cat_r2:.2f}")
print(f"Best iteration: {cat_model.get_best_iteration()}")
# Out:
# CatBoost MAE: 122193.21
# CatBoost RMSE: 222494.46
# CatBoost R2: 0.82
# Best iteration: 428

# %% [markdown]
# ---

# %% [markdown]
# # Model Performance Comparison Graph

# %% [markdown]
# ![Model Comparison](../media/model-performance-comparison.png)

# %% [markdown]
# *After comparing multiple regression models, XGBoost with Early Stopping achieved the best overall performance, obtaining the lowest prediction errors and the highest R² score.*
# *This confirms that gradient boosting methods are highly effective for structured tabular datasets such as used car pricing problems.*
#
# *The project also demonstrated the importance of feature engineering, especially variables such as car_age, km_per_year, and brand extraction.*

# %% [markdown]
# ---

# %% [markdown]
# # Feature Importance

# %%
encoded_features = preprocessor.named_transformers_["cat"].get_feature_names_out(categorical_features)
all_features = numerical_features + list(encoded_features)
importances = xgb_model.feature_importances_

# %%
feature_importance_df = pd.DataFrame({
    "Feature": all_features,
    "Importance": importances

}).sort_values(by="Importance",ascending=False)

# %%
feature_importance_df.head(15)
# Out:
#                          Feature  Importance
# 10        transmission_Automatic    0.282090
# 13                     brand_BMW    0.137617
# 4                    fuel_Diesel    0.099861
# 22           brand_Mercedes-Benz    0.098942
# 24                   brand_Other    0.062271
# 12                    brand_Audi    0.057109
# 2                        car_age    0.043240
# 28                  brand_Toyota    0.039609
# 21                  brand_Maruti    0.033684
# 26                   brand_Skoda    0.020500
# 9   seller_type_Trustmark Dealer    0.019198
# 7             seller_type_Dealer    0.013608
# 27                    brand_Tata    0.008901
# 14               brand_Chevrolet    0.008604
# 0                      km_driven    0.008324

# %% [markdown]
# ---

# %% [markdown]
# *The model suggests that vehicle configuration and brand prestige are stronger pricing drivers than mileage alone in this dataset.*

# %% [markdown]
# ![fEature importance](../media/feature-importance.png)

# %% [markdown]
# # Final Conclusions

# %% [markdown]
# *<u>This project developed a machine learning system</u> to predict used car prices using **real market variables** such as ``brand``, ``mileage``, ``age``, ``fuel type``, ``transmission``, and ``seller information``.
# Several **regression models** were evaluated, including **Linear Regression**, **Random Forest**, **XGBoost**, and **CatBoost**.
# Among all tested approaches, **XGBoost** with *Early Stopping* achieved the best overall performance, obtaining the lowest prediction errors and the highest explanatory power **(R² = 0.89)**.
# Feature importance analysis revealed that ``transmission type``, ``premium brands``, ``fuel type``, and ``vehicle age`` were among the *most influentia*l factors affecting *price prediction*.
# The project demonstrates the importance of **data preprocessing**, **feature engineering**, and **model selection** when <u>solving structured tabular machine learning problems</u>.*

# %% [markdown]
# ---

# %% [markdown]
# # Final Model Serialization

# %%
import joblib

joblib.dump(xgb_model, "../models/xgb_used_car_model.pkl")
# Out:
# ['../models/xgb_used_car_model.pk1']

# %% [markdown]
# ---

# %% [markdown]
# **Authorship:** *Héctor Ayuso Martín*
#
# **Linkedin:** *https://www.linkedin.com/in/hector-ayuso-martin/*
